# %%
# Just testing the distance sampler
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
sys.path.append('../hebe/utils/')
from path_length_sampling import path_length_sampling

# %%
samples = 1000
samp_pi = path_length_sampling(np.ones(samples), 211)
samp_p = path_length_sampling(np.ones(samples), 2212)

# %%
plt.hist(samp_pi)
plt.hist(samp_p)
# Out:
# (array([526., 249., 121.,  65.,  20.,  13.,   3.,   1.,   1.,   1.]),
#  array([3.05721724e-03, 7.16296420e+01, 1.43256227e+02, 2.14882812e+02,
#         2.86509396e+02, 3.58135981e+02, 4.29762566e+02, 5.01389151e+02,
#         5.73015735e+02, 6.44642320e+02, 7.16268905e+02]),
#  <BarContainer object of 10 artists>)
